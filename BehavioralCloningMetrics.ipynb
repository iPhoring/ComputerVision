# %%
_historyObject= [['NoPreprocessing,NoAugmentation,NoDropout'],
                 [[0.52504667100063673, 0.54153702569883211, 0.54169259508277734, 0.54169259482314291, 0.54169259482314291], [0.54664179104477617, 0.54664179104477617, 0.54664179104477617, 0.54664179104477617, 0.54664179104477617]], [[0.071939496066729586, 0.014244560467562619, 0.01546826414756973, 0.013143014795927525, 0.012308584332324717], [0.014525597567544945, 0.014571327363970267, 0.013063883575708118, 0.011765988302690473, 0.011295995193149024]]]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# summarize history for accuracy
plt.plot(_historyObject[1][0]) # _historyObject.history['acc'])
plt.plot(_historyObject[1][1])#_historyObject.history['val_acc'])
plt.title('model accuracy'+str(_historyObject[0]))
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# # summarize history for loss
plt.plot(_historyObject[2][0]) #_historyObject.history['loss'])
plt.plot(_historyObject[2][1]) #_historyObject.history['val_loss'])
plt.title('model loss'+str(_historyObject[0]))
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
_historyObject= [['NoPreprocessing,Augmentation,NoDropout'], [[0.53908376760205368, 0.5421949132814502, 0.54196157735549544, 0.54203935599748032, 0.5421171346394652], [0.54463452603175522, 0.54463452603175522, 0.54463452603175522, 0.54463452603175522, 0.54432348404108644]], [[0.027604690223119233, 0.011061226385898012, 0.011100962702142902, 0.016451149896115232, 0.015456136513089674], [0.011940874021448207, 0.010643501109320492, 0.018941720270060733, 0.015592532110158614, 0.016852622665464879]]]

# %%
#### summarize history for accuracy
plt.plot(_historyObject[1][0]) # _historyObject.history['acc'])
plt.plot(_historyObject[1][1])#_historyObject.history['val_acc'])
plt.title('model accuracy'+str(_historyObject[0]))
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# # summarize history for loss
plt.plot(_historyObject[2][0]) #_historyObject.history['loss'])
plt.plot(_historyObject[2][1]) #_historyObject.history['val_loss'])
plt.title('model loss'+str(_historyObject[0]))
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
_historyObject= [['Preprocessing,Augmentation,NoDropout'], [[0.53939488221171705, 0.54413937937279666, 0.54413937937279666, 0.54413937925689748, 0.54406160073081178], [0.53685847600548298, 0.53685847600548298, 0.53685847600548298, 0.53685847600548298, 0.53685847600548298]], [[0.024533197519020205, 0.01029384871000931, 0.0094022722680843426, 0.0086839006592347116, 0.0088010633729692055], [0.010758830205440335, 0.010325032712465867, 0.010001720143641413, 0.0099730985375297947, 0.010418252698196502]]]

# %%
# summarize history for accuracy
plt.plot(_historyObject[1][0]) # _historyObject.history['acc'])
plt.plot(_historyObject[1][1])#_historyObject.history['val_acc'])
plt.title('model accuracy'+str(_historyObject[0]))
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# # summarize history for loss
plt.plot(_historyObject[2][0]) #_historyObject.history['loss'])
plt.plot(_historyObject[2][1]) #_historyObject.history['val_loss'])
plt.title('model loss'+str(_historyObject[0]))
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
_historyObject= [['Preprocessing,Augmentation,Dropout'], [[0.53519483539618085, 0.54071711897710961, 0.54071711897710961, 0.54071711897710961, 0.54079489773499367], [0.55054432354855876, 0.55054432354855876, 0.55054432354855876, 0.55054432354855876, 0.55054432354855876]], [[0.023488442624807634, 0.010475576791280377, 0.0095293977159994873, 0.0090728142303321564, 0.0083976834372273875], [0.011665460864780109, 0.01164974858911931, 0.011676057556160316, 0.011753541999967251, 0.011417626186880872]]]

# %%
# summarize history for accuracy
plt.plot(_historyObject[1][0]) # _historyObject.history['acc'])
plt.plot(_historyObject[1][1])#_historyObject.history['val_acc'])
plt.title('model accuracy'+str(_historyObject[0]))
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# # summarize history for loss
plt.plot(_historyObject[2][0]) #_historyObject.history['loss'])
plt.plot(_historyObject[2][1]) #_historyObject.history['val_loss'])
plt.title('model loss'+str(_historyObject[0]))
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
_historyObject= [['Preprocessing,Augmentation,Dropout,Activation-elu'], [[0.54071711900956132, 0.54452827258272118, 0.54452827246682201, 0.54452827246682201, 0.54468382975079177], [0.535303266311693, 0.535303266311693, 0.535303266311693, 0.535303266311693, 0.535303266311693]], [[0.020856475963449139, 0.010822201326160295, 0.0099236151271821244, 0.0091748743325192565, 0.0087680821148004278], [0.011230285729326505, 0.010710967724062329, 0.011064679256146469, 0.010353881898763391, 0.010944150409097806]]]

# %%
# summarize history for accuracy
plt.plot(_historyObject[1][0]) # _historyObject.history['acc'])
plt.plot(_historyObject[1][1])#_historyObject.history['val_acc'])
plt.title('model accuracy'+str(_historyObject[0]))
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# # summarize history for loss
plt.plot(_historyObject[2][0]) #_historyObject.history['loss'])
plt.plot(_historyObject[2][1]) #_historyObject.history['val_loss'])
plt.title('model loss'+str(_historyObject[0]))
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
_historyObject= [['Preprocessing,Augmentation,Dropout,Activation-elu,MoreData'], [[0.57362440191387565, 0.57565789473684215, 0.57565789473684215, 0.57565789473684215, 0.57565789473684215], [0.58397129203714249, 0.58397129175195284, 0.58397129203714249, 0.58397129203714249, 0.58397129175195284]], [[0.02225396130635051, 0.013189682236128446, 0.012358722077352865, 0.011646049811045804, 0.011295160709581734], [0.014551265776585163, 0.013311863310955928, 0.013169125811548894, 0.0132609846079321, 0.013097589643021519]]]

# %%
# summarize history for accuracy
plt.plot(_historyObject[1][0]) # _historyObject.history['acc'])
plt.plot(_historyObject[1][1])#_historyObject.history['val_acc'])
plt.title('model accuracy'+str(_historyObject[0]))
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# # summarize history for loss
plt.plot(_historyObject[2][0]) #_historyObject.history['loss'])
plt.plot(_historyObject[2][1]) #_historyObject.history['val_loss'])
plt.title('model loss'+str(_historyObject[0]))
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
_historyObject= [['NoPreprocessing,Augmentation,Dropout,Activation-elu,Moredata'], [[0.57751196172248809, 0.5799043062200957, 0.57984449760765555, 0.57996411483253585, 0.58002392344497611], [0.56698564604709023, 0.56698564604709023, 0.56698564604709023, 0.56698564604709023, 0.56698564604709023]], [[0.026285454330511354, 0.011565204892467939, 0.010102116609767578, 0.0088449018486022376, 0.0078183359907645928], [0.013218234454473239, 0.012908614833246578, 0.014449183507399125, 0.014146919758838901, 0.013126741087679087]]]

# %%
# summarize history for accuracy
plt.plot(_historyObject[1][0]) # _historyObject.history['acc'])
plt.plot(_historyObject[1][1])#_historyObject.history['val_acc'])
plt.title('model accuracy'+str(_historyObject[0]))
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# # summarize history for loss
plt.plot(_historyObject[2][0]) #_historyObject.history['loss'])
plt.plot(_historyObject[2][1]) #_historyObject.history['val_loss'])
plt.title('model loss'+str(_historyObject[0]))
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
_historyObject= [['NoPreprocessing,Augmentation,Dropout,Activation-elu,MoreData,AllCamera'], [[0.19230462519936203, 0.19284290271132376, 0.19290271132376396, 0.192085326953748, 0.19286283891547049], [0.1972886762550573, 0.1972886762550573, 0.1972886762550573, 0.1972886762550573, 0.1972886762550573]], [[0.024196897124191315, 0.01172868491609416, 0.010919523054059518, 14.104962143819909, 0.046141189390249797], [0.01165316416339821, 0.011241728013925005, 0.011995597308771937, 0.051923185971935397, 0.045601013245765099]]]

# %%
# summarize history for accuracy
plt.plot(_historyObject[1][0]) # _historyObject.history['acc'])
plt.plot(_historyObject[1][1])#_historyObject.history['val_acc'])
plt.title('model accuracy'+str(_historyObject[0]))
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# # summarize history for loss
plt.plot(_historyObject[2][0]) #_historyObject.history['loss'])
plt.plot(_historyObject[2][1]) #_historyObject.history['val_loss'])
plt.title('model loss'+str(_historyObject[0]))
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
